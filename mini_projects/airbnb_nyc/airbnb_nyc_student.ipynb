# %% [markdown]
# # Mini-Project: NYC Airbnb Price Prediction
#
# Before you begin, make sure to read the guidelines and requirements in the `README.md` file. Good luck!

# %% [markdown]
# ## Global Setup and Imports
# Don't forget to import necessary libraries as you go.

# %%
import os
import urllib.request

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Fix random_state for reproducibility
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)

# %% [markdown]
# ## Phase 1: Exploratory Data Analysis (EDA)

# %%
# Automatically download the dataset if it's not present locally
DATA_FILE = 'AB_NYC_2019.csv'
DATA_URL = 'https://raw.githubusercontent.com/alexeygrigorev/datasets/master/AB_NYC_2019.csv'

if not os.path.exists(DATA_FILE):
    print('Downloading dataset...')
    urllib.request.urlretrieve(DATA_URL, DATA_FILE)
    print('Done.')

df = pd.read_csv(DATA_FILE)
print('Dataset shape:', df.shape)

# %%
# TODO: Explore data structure, column types, and explicitly look for anomalies (e.g., zero prices)

# %%
# TODO: Assess the scale of missing values in the dataset

# %%
# TODO: Plot the distribution of the target variable - price

# %%
# TODO: Create a scatter plot of geographical coordinates (latitude, longitude)

# %% [markdown]
# ## Phase 2: Data Preprocessing

# %%
# TODO: Handle missing values (fill or drop, briefly justifying your choice)

# %%
# TODO: Drop ID columns and raw text names that cannot be used directly without NLP

# %%
# TODO: Encode categorical features (OneHotEncoder / pd.get_dummies)

# %%
# TODO: Split the data into features (X) and target (y), then into train and test sets

# %% [markdown]
# ## Phase 3: Model Training
# It's highly recommended to use `sklearn.pipeline.Pipeline`.

# %%
# TODO: Train a baseline linear model (LinearRegression, Ridge, or Lasso)

# %%
# TODO: Train a tree-based ensemble model (RandomForestRegressor or HistGradientBoostingRegressor)

# %% [markdown]
# ## Phase 4: Evaluation and Analysis

# %%
# TODO: Evaluate RMSE, MAE, and R^2 metrics on the test set for all models

# %%
# TODO: Build a final comparison table for the trained models

# %%
# TODO: Plot the Feature Importance for your best tree-based model

# %% [markdown]
# ## Phase 5: Business Conclusions
#
# *Your text answer here:*
# 1. Which model turned out to be the best and why?
# 2. Which features have the strongest impact on the price?
# 3. What does your model lack to significantly improve prediction quality?
